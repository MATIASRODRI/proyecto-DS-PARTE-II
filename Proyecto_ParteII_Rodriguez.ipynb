# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

credit = pd.read_csv('C://Users/USURIO/Desktop/Nueva carpeta/001 ENTREGA 1/set 3/credit_card_churn.csv')

sns.countplot(data=credit, x="Attrition_Flag", hue="Gender")
# Out:
# <AxesSubplot:xlabel='Attrition_Flag', ylabel='count'>

# %%
#sns.countplot(data=credit, x="Education_Level", hue="Gender")
sns.displot(data=credit, x="Education_Level",hue="Gender",col="Gender")

# %%
sns.countplot(data=credit, x="Marital_Status", hue="Gender")
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(data=credit, x="Card_Category", hue="Income_Category")
# Out:
# <AxesSubplot:xlabel='Card_Category', ylabel='count'>

# %%
sns.displot(data=credit, x="Dependent_count", hue="Income_Category", col="Income_Category")
#sns.countplot(data=credit, x="Dependent_count", hue = "Income_Category", col = "Income_Category")

# Solo el genero se distribuye de manera uniforme en los recuentos realizados.
# La tarjeta azul, es la mas requerida pese a las diferencias de poder adquisitivo
# La distribución de dependientes no resulta uniforme, tiene aspecto de distribución "gaus" con una dispersión significativa.

# %%
sns.displot(data=credit, x="Customer_Age", hue="Education_Level", col="Education_Level")

# %%
sns.displot(data=credit, x="Months_Inactive_12_mon", hue="Education_Level", col="Education_Level")

# %%
sns.displot(data=credit, x="Credit_Limit", hue="Education_Level", col="Education_Level")

# %%
sns.displot(data=credit, x="Total_Revolving_Bal", hue="Education_Level", col="Education_Level")

# %%
sns.displot(data=credit, x="Total_Amt_Chng_Q4_Q1", hue="Education_Level", col="Education_Level")

# %%
sns.displot(data=credit, x="Total_Ct_Chng_Q4_Q1", hue="Education_Level", col="Education_Level")

# %%
#Observaciones
# A partir de las distribuciones, la edad de captación de clientes está entre 40 y 50 años
# El recuento de dependientes es multimodal, pero parece simétrico desde ambos lados
# Meses inactivo, tiene una distribución multimodal
# El saldo rotativo total es multimodal con la mayoría del saldo rotativo 0 
# Total amt_change Q4_over_Q1 queda sesgado, siendo la mayoría 05 y 10, indica que la transacción ha sido menor en el Q4 en comparación con el Q1
# otal_Ct_Chng_Q4_Q1, no aporta nueva información

# %%
credit.groupby('Income_Category').aggregate({'Card_Category':'value_counts'})
plt.figure(figsize=(12,8))
sns.countplot(data=credit,x='Income_Category',hue='Card_Category')
plt.title('Categoria de Ingresos con respecto a la tarjeta elegida')
plt.show()
# Se observa que pese al poder adquisitivo la tarjeta azul es la mas elegida
